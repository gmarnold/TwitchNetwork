# %%
pip install python-twitch-client
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install python-twitch-client
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
from twitch import TwitchClient

# %%
client = TwitchClient(client_id='45smruax3qg6qh72lnf9ykcoqm3cm5', oauth_token='tt1egaliva2jya3h130oqs1ixa9fex')

# %%
client = TwitchClient(client_id='45smruax3qg6qh72lnf9ykcoqm3cm5')

# %%
pip install twitchAPI
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install twitchAPI
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
from twitchAPI.twitch import Twitch
from pprint import pprint
twitch = Twitch('45smruax3qg6qh72lnf9ykcoqm3cm5', 'tt1egaliva2jya3h130oqs1ixa9fex')
pprint(twitch.get_users(logins=['serenegrachay']))
# Out:
# {'data': [{'broadcaster_type': '',
#            'created_at': '2018-03-07T22:25:20Z',
#            'description': 'Gamer. Guinness World Record Holder. Cat Owner.',
#            'display_name': 'SereneGrachay',
#            'id': '203571765',
#            'login': 'serenegrachay',
#            'offline_image_url': '',
#            'profile_image_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/7f0ebcd0-1016-4fa0-b3c3-a088e4751c6f-profile_image-300x300.png',
#            'type': '',
#            'view_count': 951}]}

# %%
pprint(twitch.get_users(logins=['gentlemangarby']))
# Out:
# {'data': [{'broadcaster_type': 'affiliate',
#            'created_at': '2013-01-21T23:46:19Z',
#            'description': "Hey guys! Garby here! I'm here to help educate the "
#                           'masses in the wonders of competitive Pokemon. I '
#                           'have played competitive pokemon for over 10 years, '
#                           'but have just recently focused more time in the '
#                           'official Nintendo support format, VGC. Hope you '
#                           'enjoy the content and learn a thing or two! ',
#            'display_name': 'GentlemanGarby',
#            'id': '39567248',
#            'login': 'gentlemangarby',
#            'offline_image_url': '',
#            'profile_image_url': 'https://static-cdn.jtvnw.net/jtv_user_pictures/793a17ea-1309-4d53-93f9-86edf7c294d2-profile_image-300x300.png',
#            'type': '',
#            'view_count': 2371}]}

# %%
pprint(twitch.get_users_follows(from_id=203571765, after='eyJiIjpudWxsLCJhIjp7IkN1cnNvciI6ImV5SjBjQ0k2SW5WelpYSTZNakF6TlRjeE56WTFPbVp2Ykd4dmQzTWlMQ0owY3lJNkluVnpaWEk2TWpNeU56QTVNak0zSWl3aWFYQWlPaUoxYzJWeU9qSXdNelUzTVRjMk5UcG1iMnhzYjNkeklpd2lhWE1pT2lJeE5qRTFNakkyTURNd05UVTVOalkwTkRRekluMD0ifX0'))
# Out:
# {'data': [{'followed_at': '2021-03-08T01:07:11Z',
#            'from_id': '203571765',
#            'from_login': 'serenegrachay',
#            'from_name': 'SereneGrachay',
#            'to_id': '131088258',
#            'to_login': 'ichijis',
#            'to_name': 'ichijis'},
#           {'followed_at': '2021-03-05T17:26:09Z',
#            'from_id': '203571765',
#            'from_login': 'serenegrachay',
#            'from_name': 'SereneGrachay',
#            'to_id': '68525019',
#            'to_login': 'shadowatnoon',
#            'to_name': 'shadowatnoon'},
#           {'followed_at': '2021-03-05T06:16:07Z',
#            'from_id': '203571765',
#            'from_login': 'serenegrachay',
#            'from_name': 'SereneGrachay',
#            'to_id': '585440354',
#            'to_login': 'totally_not_erick',
#            'to_name': 'totally_not_erick'},
#           {'followed_at': '2021-02-26T02:08:01Z',
#            'from_id': '203571765',
#            'from_login': 'serenegrachay',
#            'from_name': 'SereneGrachay',
#            'to_id': '529409390',
#            'to_login': 'atx_vgc',
#            'to_name': 'ATX_VGC'},
#           {'followed_at': '2021-02-25T20:02:22Z',
#            'from_id': '203571765',
#            'from_login': 'serenegrachay',
#            'from_name': 'SereneGrachay',
#            'to_id': '26058558',
#            'to_login': 'glitchxcity',
#            'to_name': 'GlitchxCity'},
#           {'followed_at': '2021-02-20T23:38:04Z',
#            'from_id': '203571765',
#            'from_login': 'serenegrachay',
#            'from_name': 'SereneGrachay',
#            'to_id': '147102854',
#            'to_login': 'galaxiangod',
#            'to_name': 'galaxiangod'},
#           {'followed_at': '2021-02-19T02:21:52Z',
#            'from_id': '203571765',
#            'from_login': 'serenegrachay',
#            'from_name': 'SereneGrachay',
#            'to_id': '115539870',
#            'to_login': 'freehenry',
#            'to_name': 'FreeHenry'},
#           {'followed_at': '2021-02-17T01:21:37Z',
#            'from_id': '203571765',
#            'from_login': 'serenegrachay',
#            'from_name': 'SereneGrachay',
#            'to_id': '113673640',
#            'to_login': 'louthepikachu',
#            'to_name': 'LouThePikachu'},
#           {'followed_at': '2021-02-14T21:30:31Z',
#            'from_id': '203571765',
#            'from_login': 'serenegrachay',
#            'from_name': 'SereneGrachay',
#            'to_id': '51036255',
#            'to_login': 'obstructionsz',
#            'to_name': 'Obstructionsz'},
#           {'followed_at': '2021-02-10T02:16:25Z',
#            'from_id': '203571765',
#            'from_login': 'serenegrachay',
#            'from_name': 'SereneGrachay',
#            'to_id': '22407530',
#            'to_login': 'pkmncast',
#            'to_name': 'PKMNcast'},
#           {'followed_at': '2021-02-10T01:04:43Z',
#            'from_id': '203571765',
#            'from_login': 'serenegrachay',
#            'from_name': 'SereneGrachay',
#            'to_id': '558919332',
#            'to_login': 'honeybeegirl122',
#            'to_name': 'honeybeegirl122'},
#           {'followed_at': '2021-02-08T01:32:12Z',
#            'from_id': '203571765',
#            'from_login': 'serenegrachay',
#            'from_name': 'SereneGrachay',
#            'to_id': '636767237',
#            'to_login': 'sarahvgc',
#            'to_name': 'SarahVGC'},
#           {'followed_at': '2021-02-07T21:18:59Z',
#            'from_id': '203571765',
#            'from_login': 'serenegrachay',
#            'from_name': 'SereneGrachay',
#            'to_id': '105774203',
#            'to_login': 'luckyw0lf',
#            'to_name': 'luckyw0lf'},
#           {'followed_at': '2021-02-06T21:07:18Z',
#            'from_id': '203571765',
#            'from_login': 'serenegrachay',
#            'from_name': 'SereneGrachay',
#            'to_id': '125494279',
#            'to_login': 'victoryroadvgc',
#            'to_name': 'VictoryRoadVGC'},
#           {'followed_at': '2021-02-03T02:18:42Z',
#            'from_id': '203571765',
#            'from_login': 'serenegrachay',
#            'from_name': 'SereneGrachay',
#            'to_id': '174711665',
#            'to_login': '45mice',
#            'to_name': '45mice'},
#           {'followed_at': '2021-02-01T19:52:25Z',
#            'from_id': '203571765',
#            'from_login': 'serenegrachay',
#            'from_name': 'SereneGrachay',
#            'to_id': '43105188',
#            'to_login': 'taninomori',
#            'to_name': 'taninoMori'},
#           {'followed_at': '2021-01-31T01:22:55Z',
#            'from_id': '203571765',
#            'from_login': 'serenegrachay',
#            'from_name': 'SereneGrachay',
#            'to_id': '16226352',
#            'to_login': 'bakingpanda',
#            'to_name': 'BakingPanda'},
#           {'followed_at': '2021-01-28T01:59:59Z',
#            'from_id': '203571765',
#            'from_login': 'serenegrachay',
#            'from_name': 'SereneGrachay',
#            'to_id': '195515346',
#            'to_login': 'aspoon13',
#            'to_name': 'ASpoon13'},
#           {'followed_at': '2021-01-22T03:17:19Z',
#            'from_id': '203571765',
#            'from_login': 'serenegrachay',
#            'from_name': 'SereneGrachay',
#            'to_id': '89519770',
#            'to_login': 'sombracurse',
#            'to_name': 'SombraCurse'},
#           {'followed_at': '2021-01-21T03:20:23Z',
#            'from_id': '203571765',
#            'from_login': 'serenegrachay',
#            'from_name': 'SereneGrachay',
#            'to_id': '99678046',
#            'to_login': 's7ormking',
#            'to_name': 'S7ormking'}],
#  'pagination': {'cursor': 'eyJiIjpudWxsLCJhIjp7IkN1cnNvciI6ImV5SjBjQ0k2SW5WelpYSTZNakF6TlRjeE56WTFPbVp2Ykd4dmQzTWlMQ0owY3lJNkluVnpaWEk2T1RrMk56Z3dORFlpTENKcGNDSTZJblZ6WlhJNk1qQXpOVGN4TnpZMU9tWnZiR3h2ZDNNaUxDSnBjeUk2SWpFMk1URXhPVGt5TWpNNU5qTTRPVGswTVRVaWZRPT0ifX0'},
#  'total': 136}

# %%
import json

# %%
following = twitch.get_users_follows(from_id=203571765)

# %%
following
# Out:
# {'total': 136,
#  'data': [{'from_id': '203571765',
#    'from_login': 'serenegrachay',
#    'from_name': 'SereneGrachay',
#    'to_id': '28822180',
#    'to_login': 'darkragaming',
#    'to_name': 'DarkRaGaming',
#    'followed_at': '2021-09-24T16:19:27Z'},
#   {'from_id': '203571765',
#    'from_login': 'serenegrachay',
#    'from_name': 'SereneGrachay',
#    'to_id': '517430904',
#    'to_login': 'princesskiraxo',
#    'to_name': 'princesskiraxo',
#    'followed_at': '2021-09-12T00:04:38Z'},
#   {'from_id': '203571765',
#    'from_login': 'serenegrachay',
#    'from_name': 'SereneGrachay',
#    'to_id': '634476243',
#    'to_login': 'voiceofkris',
#    'to_name': 'VoiceofKris',
#    'followed_at': '2021-09-11T23:48:58Z'},
#   {'from_id': '203571765',
#    'from_login': 'serenegrachay',
#    'from_name': 'SereneGrachay',
#    'to_id': '119582812',
#    'to_login': 'sandybeach_irl',
#    'to_name': 'SandyBeach_IRL',
#    'followed_at': '2021-09-11T04:09:40Z'},
#   {'from_id': '203571765',
#    'from_login': 'serenegrachay',
#    'from_name': 'SereneGrachay',
#    'to_id': '100816368',
#    'to_login': 't_royjenkins',
#    'to_name': 'T_RoyJenkins',
#    'followed_at': '2021-09-06T23:07:37Z'},
#   {'from_id': '203571765',
#    'from_login': 'serenegrachay',
#    'from_name': 'SereneGrachay',
#    'to_id': '127328436',
#    'to_login': 'xthe_developer',
#    'to_name': 'xThe_Developer',
#    'followed_at': '2021-08-25T02:42:41Z'},
#   {'from_id': '203571765',
#    'from_login': 'serenegrachay',
#    'from_name': 'SereneGrachay',
#    'to_id': '141981764',
#    'to_login': 'twitchdev',
#    'to_name': 'TwitchDev',
#    'followed_at': '2021-08-23T23:37:25Z'},
#   {'from_id': '203571765',
#    'from_login': 'serenegrachay',
#    'from_name': 'SereneGrachay',
#    'to_id': '597316278',
#    'to_login': 'mastershef0e',
#    'to_name': 'MASTERSHEF0E',
#    'followed_at': '2021-08-23T02:30:01Z'},
#   {'from_id': '203571765',
#    'from_login': 'serenegrachay',
#    'from_name': 'SereneGrachay',
#    'to_id': '162761277',
#    'to_login': 'tomkill115',
#    'to_name': 'TomKILL115',
#    'followed_at': '2021-08-22T02:29:04Z'},
#   {'from_id': '203571765',
#    'from_login': 'serenegrachay',
#    'from_name': 'SereneGrachay',
#    'to_id': '217814966',
#    'to_login': 'professortwigg',
#    'to_name': 'professortwigg',
#    'followed_at': '2021-08-06T20:26:37Z'},
#   {'from_id': '203571765',
#    'from_login': 'serenegrachay',
#    'from_name': 'SereneGrachay',
#    'to_id': '177495378',
#    'to_login': 'boardingpartydmdrew',
#    'to_name': 'BoardingPartyDMDrew',
#    'followed_at': '2021-08-06T20:19:16Z'},
#   {'from_id': '203571765',
#    'from_login': 'serenegrachay',
#    'from_name': 'SereneGrachay',
#    'to_id': '220046959',
#    'to_login': 'briandavidgilbert',
#    'to_name': 'briandavidgilbert',
#    'followed_at': '2021-08-05T16:10:18Z'},
#   {'from_id': '203571765',
#    'from_login': 'serenegrachay',
#    'from_name': 'SereneGrachay',
#    'to_id': '32956898',
#    'to_login': 'indiebear',
#    'to_name': 'indiebear',
#    'followed_at': '2021-08-02T03:28:28Z'},
#   {'from_id': '203571765',
#    'from_login': 'serenegrachay',
#    'from_name': 'SereneGrachay',
#    'to_id': '143839825',
#    'to_login': 'uleejulie',
#    'to_name': 'uLeeJulie',
#    'followed_at': '2021-07-20T15:47:00Z'},
#   {'from_id': '203571765',
#    'from_login': 'serenegrachay',
#    'from_name': 'SereneGrachay',
#    'to_id': '188264612',
#    'to_login': 'heyboyblue',
#    'to_name': 'heyboyblue',
#    'followed_at': '2021-07-16T01:34:36Z'},
#   {'from_id': '203571765',
#    'from_login': 'serenegrachay',
#    'from_name': 'SereneGrachay',
#    'to_id': '18384018',
#    'to_login': 'thenoble1',
#    'to_name': 'thenoble1',
#    'followed_at': '2021-07-15T02:19:26Z'},
#   {'from_id': '203571765',
#    'from_login': 'serenegrachay',
#    'from_name': 'SereneGrachay',
#    'to_id': '593834008',
#    'to_login': 'yuppypika',
#    'to_name': 'YuppyPika',
#    'followed_at': '2021-07-11T18:36:10Z'},
#   {'from_id': '203571765',
#    'from_login': 'serenegrachay',
#    'from_name': 'SereneGrachay',
#    'to_id': '65469220',
#    'to_login': 'sammysmoothbrain',
#    'to_name': 'SammySmoothbrain',
#    'followed_at': '2021-06-01T00:34:53Z'},
#   {'from_id': '203571765',
#    'from_login': 'serenegrachay',
#    'from_name': 'SereneGrachay',
#    'to_id': '200394185',
#    'to_login': 'anuntitledfolder',
#    'to_name': 'AnUntitledFolder',
#    'followed_at': '2021-05-13T05:37:10Z'},
#   {'from_id': '203571765',
#    'from_login': 'serenegrachay',
#    'from_name': 'SereneGrachay',
#    'to_id': '524564941',
#    'to_login': 'cotnn',
#    'to_name': 'cotnn',
#    'followed_at': '2021-05-13T00:07:01Z'}],
#  'pagination': {'cursor': 'eyJiIjpudWxsLCJhIjp7IkN1cnNvciI6ImV5SjBjQ0k2SW5WelpYSTZNakF6TlRjeE56WTFPbVp2Ykd4dmQzTWlMQ0owY3lJNkluVnpaWEk2TlRJME5UWTBPVFF4SWl3aWFYQWlPaUoxYzJWeU9qSXdNelUzTVRjMk5UcG1iMnhzYjNkeklpd2lhWE1pT2lJeE5qSXdPRFkwTkRJeE9UUTRNVFkxTVRJNEluMD0ifX0'}}

# %%
following['data']
# Out:
# [{'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '28822180',
#   'to_login': 'darkragaming',
#   'to_name': 'DarkRaGaming',
#   'followed_at': '2021-09-24T16:19:27Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '517430904',
#   'to_login': 'princesskiraxo',
#   'to_name': 'princesskiraxo',
#   'followed_at': '2021-09-12T00:04:38Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '634476243',
#   'to_login': 'voiceofkris',
#   'to_name': 'VoiceofKris',
#   'followed_at': '2021-09-11T23:48:58Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '119582812',
#   'to_login': 'sandybeach_irl',
#   'to_name': 'SandyBeach_IRL',
#   'followed_at': '2021-09-11T04:09:40Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '100816368',
#   'to_login': 't_royjenkins',
#   'to_name': 'T_RoyJenkins',
#   'followed_at': '2021-09-06T23:07:37Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '127328436',
#   'to_login': 'xthe_developer',
#   'to_name': 'xThe_Developer',
#   'followed_at': '2021-08-25T02:42:41Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '141981764',
#   'to_login': 'twitchdev',
#   'to_name': 'TwitchDev',
#   'followed_at': '2021-08-23T23:37:25Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '597316278',
#   'to_login': 'mastershef0e',
#   'to_name': 'MASTERSHEF0E',
#   'followed_at': '2021-08-23T02:30:01Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '162761277',
#   'to_login': 'tomkill115',
#   'to_name': 'TomKILL115',
#   'followed_at': '2021-08-22T02:29:04Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '217814966',
#   'to_login': 'professortwigg',
#   'to_name': 'professortwigg',
#   'followed_at': '2021-08-06T20:26:37Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '177495378',
#   'to_login': 'boardingpartydmdrew',
#   'to_name': 'BoardingPartyDMDrew',
#   'followed_at': '2021-08-06T20:19:16Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '220046959',
#   'to_login': 'briandavidgilbert',
#   'to_name': 'briandavidgilbert',
#   'followed_at': '2021-08-05T16:10:18Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '32956898',
#   'to_login': 'indiebear',
#   'to_name': 'indiebear',
#   'followed_at': '2021-08-02T03:28:28Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '143839825',
#   'to_login': 'uleejulie',
#   'to_name': 'uLeeJulie',
#   'followed_at': '2021-07-20T15:47:00Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '188264612',
#   'to_login': 'heyboyblue',
#   'to_name': 'heyboyblue',
#   'followed_at': '2021-07-16T01:34:36Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '18384018',
#   'to_login': 'thenoble1',
#   'to_name': 'thenoble1',
#   'followed_at': '2021-07-15T02:19:26Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '593834008',
#   'to_login': 'yuppypika',
#   'to_name': 'YuppyPika',
#   'followed_at': '2021-07-11T18:36:10Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '65469220',
#   'to_login': 'sammysmoothbrain',
#   'to_name': 'SammySmoothbrain',
#   'followed_at': '2021-06-01T00:34:53Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '200394185',
#   'to_login': 'anuntitledfolder',
#   'to_name': 'AnUntitledFolder',
#   'followed_at': '2021-05-13T05:37:10Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '524564941',
#   'to_login': 'cotnn',
#   'to_name': 'cotnn',
#   'followed_at': '2021-05-13T00:07:01Z'}]

# %%
following['pagination']['cursor']
# Out:
# 'eyJiIjpudWxsLCJhIjp7IkN1cnNvciI6ImV5SjBjQ0k2SW5WelpYSTZNakF6TlRjeE56WTFPbVp2Ykd4dmQzTWlMQ0owY3lJNkluVnpaWEk2TlRJME5UWTBPVFF4SWl3aWFYQWlPaUoxYzJWeU9qSXdNelUzTVRjMk5UcG1iMnhzYjNkeklpd2lhWE1pT2lJeE5qSXdPRFkwTkRJeE9UUTRNVFkxTVRJNEluMD0ifX0'

# %%
nextpage = twitch.get_users_follows(after=following['pagination']['cursor'],from_id=203571765)

# %%
nextpage['data']
# Out:
# [{'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '625560637',
#   'to_login': 'karaikouvgc',
#   'to_name': 'KaraikouVGC',
#   'followed_at': '2021-04-21T01:51:30Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '43825170',
#   'to_login': 'hamallkid',
#   'to_name': 'HamAllKid',
#   'followed_at': '2021-04-13T23:12:17Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '235282429',
#   'to_login': 'lady_brittany',
#   'to_name': 'Lady_Brittany',
#   'followed_at': '2021-03-24T01:27:44Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '37291913',
#   'to_login': 'eggrollbuddy',
#   'to_name': 'Eggrollbuddy',
#   'followed_at': '2021-03-23T04:02:06Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '138876278',
#   'to_login': 'kamihada',
#   'to_name': 'kamihada',
#   'followed_at': '2021-03-17T22:05:42Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '232709237',
#   'to_login': 'whatisoup',
#   'to_name': 'whatisoup',
#   'followed_at': '2021-03-08T17:53:50Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '131088258',
#   'to_login': 'ichijis',
#   'to_name': 'ichijis',
#   'followed_at': '2021-03-08T01:07:11Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '68525019',
#   'to_login': 'shadowatnoon',
#   'to_name': 'shadowatnoon',
#   'followed_at': '2021-03-05T17:26:09Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '585440354',
#   'to_login': 'totally_not_erick',
#   'to_name': 'totally_not_erick',
#   'followed_at': '2021-03-05T06:16:07Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '529409390',
#   'to_login': 'atx_vgc',
#   'to_name': 'ATX_VGC',
#   'followed_at': '2021-02-26T02:08:01Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '26058558',
#   'to_login': 'glitchxcity',
#   'to_name': 'GlitchxCity',
#   'followed_at': '2021-02-25T20:02:22Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '147102854',
#   'to_login': 'galaxiangod',
#   'to_name': 'galaxiangod',
#   'followed_at': '2021-02-20T23:38:04Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '115539870',
#   'to_login': 'freehenry',
#   'to_name': 'FreeHenry',
#   'followed_at': '2021-02-19T02:21:52Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '113673640',
#   'to_login': 'louthepikachu',
#   'to_name': 'LouThePikachu',
#   'followed_at': '2021-02-17T01:21:37Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '51036255',
#   'to_login': 'obstructionsz',
#   'to_name': 'Obstructionsz',
#   'followed_at': '2021-02-14T21:30:31Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '22407530',
#   'to_login': 'pkmncast',
#   'to_name': 'PKMNcast',
#   'followed_at': '2021-02-10T02:16:25Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '558919332',
#   'to_login': 'honeybeegirl122',
#   'to_name': 'honeybeegirl122',
#   'followed_at': '2021-02-10T01:04:43Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '636767237',
#   'to_login': 'sarahvgc',
#   'to_name': 'SarahVGC',
#   'followed_at': '2021-02-08T01:32:12Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '105774203',
#   'to_login': 'luckyw0lf',
#   'to_name': 'luckyw0lf',
#   'followed_at': '2021-02-07T21:18:59Z'},
#  {'from_id': '203571765',
#   'from_login': 'serenegrachay',
#   'from_name': 'SereneGrachay',
#   'to_id': '125494279',
#   'to_login': 'victoryroadvgc',
#   'to_name': 'VictoryRoadVGC',
#   'followed_at': '2021-02-06T21:07:18Z'}]

# %%
followtotal = [following]
page = following['pagination']['cursor']
count = 0
while page is not '':
    followtotal += twitch.get_users_follows(from_id=203571765, after=page)
    print("Here:",followtotal[count]['pagination']['cursor'])
    page = followtotal[count]['pagination']['cursor']
    count+=1
# Out:
# Here: eyJiIjpudWxsLCJhIjp7IkN1cnNvciI6ImV5SjBjQ0k2SW5WelpYSTZNakF6TlRjeE56WTFPbVp2Ykd4dmQzTWlMQ0owY3lJNkluVnpaWEk2TlRJME5UWTBPVFF4SWl3aWFYQWlPaUoxYzJWeU9qSXdNelUzTVRjMk5UcG1iMnhzYjNkeklpd2lhWE1pT2lJeE5qSXdPRFkwTkRJeE9UUTRNVFkxTVRJNEluMD0ifX0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-59dcbe893f82> in <module>
#       4 while page is not '':
#       5     followtotal += twitch.get_users_follows(from_id=203571765, after=page)
# ----> 6     print("Here:",followtotal[count]['pagination']['cursor'])
#       7     page = followtotal[count]['pagination']['cursor']
#       8     count+=1
#
# TypeError: string indices must be integers

# %%
following

# %%
following['pagination']

# %%
following = twitch.get_users_follows(from_id=203571765)

# %%
following_ids = []

for i in following['data']:
    following_ids.append(i['to_id'])

following_ids

# %%
for i in range(len(following["data"])):
    print(following['data'][i]['to_name'])

# %% [markdown]
# # Get Users Follows

# %% [markdown]
# ## Prototype

# %%
#following_names = []
def getNodes(twitchGetFollowers):
    fn = []
    following = twitchGetFollowers
    count = 0
    for i in range(len(following["data"])):
        #print(i)
        #following_names.append(following['data'][i]['to_id'])
        fn.append(following['data'][i]['to_id'])
        count += 1
        if count == 20 and following['pagination']['cursor'] is not '':
            print("Here")
            fn= fn + getNodes(twitch.get_users_follows(after=following['pagination']['cursor'],from_id=203571765))
            count = 0
            i = 0
    return fn

# %%
fn = getNodes(twitch.get_users_follows(from_id=203571765))

# %%
fn

# %%
len(fn)

# %%
len(following_names)

# %% [markdown]
# ## Finished by Gladys

# %% [markdown]
# The getNodes function recursively get the entire list of a user's follows

# %%
#twitch.get_users_follows(from_id=203571765)
def getNodes(twitchGetUserFollows): #accepts a call to twitch api to get the users follows from a certain id
    following_ids = [] #Store all ids
    following = twitchGetUserFollows #put data in a variable
    
    for i in range(len(following["data"])): #Goes through the data on the current page, default to 20
        following_ids.append(following['data'][i]['to_id']) #Appends the user's follows id's
        
        if i == 19 and following['pagination']['cursor'] is not '': #Checks if  there is another page and that we finished current page
            #Merges following_ids array with the array return recursively
            following_ids = following_ids + getNodes(twitch.get_users_follows(after=following['pagination']['cursor'],from_id=203571765))

    return following_ids

# %%
following_ids = getNodes(twitch.get_users_follows(from_id=203571765))

# %%
len(following_ids)
# Out:
# 136

# %%
following_ids
# Out:
# ['28822180',
#  '517430904',
#  '634476243',
#  '119582812',
#  '100816368',
#  '127328436',
#  '141981764',
#  '597316278',
#  '162761277',
#  '217814966',
#  '177495378',
#  '220046959',
#  '32956898',
#  '143839825',
#  '188264612',
#  '18384018',
#  '593834008',
#  '65469220',
#  '200394185',
#  '524564941',
#  '625560637',
#  '43825170',
#  '235282429',
#  '37291913',
#  '138876278',
#  '232709237',
#  '131088258',
#  '68525019',
#  '585440354',
#  '529409390',
#  '26058558',
#  '147102854',
#  '115539870',
#  '113673640',
#  '51036255',
#  '22407530',
#  '558919332',
#  '636767237',
#  '105774203',
#  '125494279',
#  '174711665',
#  '43105188',
#  '16226352',
#  '195515346',
#  '89519770',
#  '99678046',
#  '416169919',
#  '464548096',
#  '119769744',
#  '518441424',
#  '247756223',
#  '44153751',
#  '540154738',
#  '144140503',
#  '127796894',
#  '186970893',
#  '117756065',
#  '434137378',
#  '57363360',
#  '62666394',
#  '108328030',
#  '455388822',
#  '188199091',
#  '83021990',
#  '44327552',
#  '437025592',
#  '79753772',
#  '124992464',
#  '147653945',
#  '476325243',
#  '554466567',
#  '547225998',
#  '498085341',
#  '57873595',
#  '39567248',
#  '50754960',
#  '496805972',
#  '191056288',
#  '54870366',
#  '59520580',
#  '154429778',
#  '170434061',
#  '43495105',
#  '97730107',
#  '44044454',
#  '578706591',
#  '263811541',
#  '64921577',
#  '121057680',
#  '461973819',
#  '153371345',
#  '402544332',
#  '39624971',
#  '15678730',
#  '23523971',
#  '46929914',
#  '59546530',
#  '128189318',
#  '502483177',
#  '105714465',
#  '498689387',
#  '94768701',
#  '173852028',
#  '41913991',
#  '86052737',
#  '149439376',
#  '65056164',
#  '116512934',
#  '176510701',
#  '114332522',
#  '416997306',
#  '177251371',
#  '111839922',
#  '67822150',
#  '72730265',
#  '40628724',
#  '183429144',
#  '40842724',
#  '256094301',
#  '127086121',
#  '50860188',
#  '157521416',
#  '48908475',
#  '93374346',
#  '161575615',
#  '485744514',
#  '125869734',
#  '68344106',
#  '74656217',
#  '195968205',
#  '36653045',
#  '274666985',
#  '113669243',
#  '93468375',
#  '27121083',
#  '254119093']

# %%
for i in following_ids:

# %%
import numpy as np
import pandas as pd
